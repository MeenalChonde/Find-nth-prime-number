# %%
number = int(input('Enter number'))
c = 0
p = 0
l=[]
while p!=number+1:
    c += 1
    for i in range(2,c):
        if c%i == 0:
            break
    else:
        l.append(c)
        p+=1
print(max(l))
# Out:
# Enter number1256
# 10247
